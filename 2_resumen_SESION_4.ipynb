# %% [markdown]
# <a href="https://colab.research.google.com/github/usembergstarling-cmyk/google-colabt/blob/main/2_resumen_SESION_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
RESUMEN

# %% [markdown]
# 1959 se propone una alternativa para que las maquinas aprendan de forma autonoma
# Datos y respuestas dan reglas que propone el mismo modelo
# La maquina hace una mega observacion de ejemplos para poder predecir y tomar decisiones de forma autonoma
#
# Los cientificos de la computacion dividen el aprendizaje de la computacion en 3 regiones diferentes
# aprendizaje supervisado
# el entrenamiento de los modelos depende de datos etiquetados previamente por humanos, la tarea principal es la clasificiacion. Esta limitado por el esfuerzo humano porque requiere que el humano etiquete datos antes de operar.
# aprendizaje no supervizado
# Se enfrenta a un oceano de datos crudos sin especcion humana, usan algoritmos como kmeans, reconocen patrones de forma autonoma, detectan anomalias y es util en temas de seguridad. Simplifican datos gigantes sin perder informacion valiosa.
# aprendizaje por refuerzo
# El sistema se convierte en un agente que interactua con un entorno dinamico, entra en un ciclo de retroalimentacion, maximizando beneficios reales, buscando recompensas y evitar castigos, algoritmos como maxminimax. Prioriza el exito final en entornos de alta incertidumbre
#
# Estos metodos fueron formulados hace decadas pero fueron dejados como teorias, se revoluciono gracias al hardware que permitieron realizar los millones de calculos necesarios para que esto pudiera ser viable. De ahi siguio el arsenal tecnologico con nucleos operativos a nivel global en todo el mundo con el machinelearning.
# Funciona como un sistema de prediccion que modela los sistemas de realidad.
