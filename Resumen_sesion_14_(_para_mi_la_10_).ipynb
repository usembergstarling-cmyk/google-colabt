# %% [markdown]
# <a href="https://colab.research.google.com/github/usembergstarling-cmyk/google-colabt/blob/main/Resumen_sesion_14_(_para_mi_la_10_).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **SESION 14**
#
# **VIDEO APRENDIZAJE POR CONJUNTOS**
#
# 1. Introduccion a conjuntos
#
# Ahora se le enseña a las máquinas
#
# ¿Como varios aprendices debiles crean uno fuerte?
#
# Ejemplo de una moneda sesgada, 51% de caer en cara, luego lanzarla mil veces la posibilidad sube al 75%
#
# 2. Clasificadores de votación
#
# Multiples clasificadores distintos trabajando sobre los mismos datos
#
# por otro lado cada modelo da su voto individual
#
# Votación dura: gana la mayoria
#
# votacion blanda: promedia las probabilidades de clase de cada predictor
#
# 3. Bagging, Pasting y OOB
#
# Bagging: muestreo aleatorio de datos de entrenamiento que permite el reemplazo de instancias. Un mismo dato puede ser escogido varias veces por un predictor.
#
# Pasting: Hace lo mismo pero sin reemplazar. Este se lleva la victoria porque disminuye la varianza
#
# Los calculos se reducen solo a segundos
#
# Las instancias se eligen al azar, el algoritmo procesa solo el 63%, el otro 37% son llamadas instancias fuera de bolsa
#
# 4. Bosques aleatorios
#
# Etrategias de muestreo
#
# Parches aleatorios: muestrea instancias y características
#
# Subespacios aleatorios: Muestrea solo las características
#
# Arboles extra: Umbrales de division aleatorios
#
# 5. Procesamiento
#
# Paso 1: Entrenar a un clasificador
#
# Paso 2: Aumentar peso a instancias
#
# Paso 3: Entrenar nuevo clasificador
#
# Paso 4: Repetir el ciclo secuencialmente
#
# La corrección secuencial ajusta los errores progresivamente
#
# El gradient boosting busca adivinar y corregir el error que dejo el modelo anterior
#
# Histogram Base Gradient Boosting: Responsable de procesar cantidades inmensas de informacion. es una versión más rápida y eficiente del algoritmo clásico de aprendizaje automático Gradient Boosting.Funciona agrupando (o "discretizando") los valores numéricos de las variables en intervalos discretos, similares a las barras de un histograma.
#
# 6. Aprendizaje
#
# El stacking se entrena un algoritmo supremo llamado mezclador, los de las primeras capas mandan sus predicciones hacia arriba, el mezclador lanza su predicción
#
# ¿Qupe desafíos globales resolverán estos algoritmos?
#
# ------------------------------------------------------------------------
#
# **VIDEO REDUCCION DE DIMENSIONALIDAD**
#
# 1. Maldicion de la dimensionalidad
#
# ¿Distancia de 408.25 en un hipercubo de un millón de ejes?
#
# en dimensionas altas hay mucho espacio vacío
#
# el alto riesgo de sobreajuste por datos extramadamente dispersos en espacios de alta dimensión - Maldicion de la dimensionalidad
#
# 2. Proyeccion y aprendizaje de variedades
#
# La proyección hace los datos en 3d en 2d,
#
# Aprendizaje de variedades
#
# la proyeción se usa cuando los datos en un lugar plano
#
# 3. Tutorial tecnico: PCA
#
# Encuentra el hiperparametro mas cercano a los datos y los proyecta preservando la máxima varianza.
#
# Centrar:centrar las instancias alrededor del origen
#
# Aplicar SVD: Descomponer matrices para hallar componentes principales
#
# Proyectar: Multiplicar los datos originales por los nuevos ejes d-dimensionales
#
# Proyección PCA preserva la mayor varianza, minimiza la distancia cuadratica media
#
# Debemos reducir nuestro modelo a 154 dimensiones para preservar el 95% de la varianza inicial
#
# 4. Optimizando a escala
#
# El metodo incremental tiene memoria baja y por mini-lotes
#
# El aleatorio tiene mas rapidez y la ventaja es que es estocásticos
#
# La proyección, es una dimension masiva y es más eficiente
#
# 5. LLE y otras técnicas
#
# para desenrollar el Swiss Roll se usa Locally Linear Embeding (LLE)
#
# El ecosistema tiene MDS, buscar distancias globales al comprimir el espacio
#
# Isomap: método de reducción de dimensionalidad no lineal que simplifica datos complejos de alta dimensión mientras conserva su estructura geométrica intrínseca.
#
# t-SNE: algoritmo de aprendizaje automático que sirve para reducir la cantidad de dimensiones en conjuntos de datos complejos y mostrarlos en un gráfico de dos o tres dimensiones.
#
# ¿Cómo moldeará la reducción dimensional a la IA en el futuro?
