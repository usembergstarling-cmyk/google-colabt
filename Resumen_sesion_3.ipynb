# %% [markdown]
# <a href="https://colab.research.google.com/github/usembergstarling-cmyk/google-colabt/blob/main/Resumen_sesion_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Resumen clase 3:

# %% [markdown]
# Caos a conocimiento: KDD
# Descubrimiento de conocimiento en bases de datos, un marco estructurado y riguroso.
# Tener datos no es lo mismo que tener conocimiento, necesitamos un proceso de refinamiento.
# Volumen: Millones de registros a nivel mundial,un analisis directo es fisicamente imposible, por eso necesitamos un filtrado para tener lo que de verdad importa.
# 1.Valor de los dato
# informacion bruta guargada en los servidores
# 2.Origenes y conceptos
# El valor final es el conocimiento no los datos en bruto, proceden a hacer el kdd y luego el jdds expandiendo al big data
# 3 tutorial proceso kdd
# ilustrados por Fayyad en 1996, seleccion, preproceso, transformacion, mineria, evaluacion y todo se hace de forma iterativa.
# Seleccion: Aislar solo lo que nos sirve
# preproceso: Limpiar en crudo
# transformacion: da una estructura matematica a esos datos ya limpios
# mineria: Soltamos modelos de clasificacion o algoritmos de agrupamiento para que busquen de forma autonoma esos patrones valiosos que el ojo humano no podria hacerlo
# Evaluacion:
# 4 aplicaciones en tiempo real
# Finanzas y usos de los datos al mundo real
# 5 el futuro del conocimiento
# Temas como la seguridad y la privacidad se vuelven criticos y la metodologia KDD puede poner en riesgo informacion muy sensible, debemos manejar esa informacion con muchisima cuidadocidad
# La invasion a la privacidad se conecta al reconocimiento de patrones.
