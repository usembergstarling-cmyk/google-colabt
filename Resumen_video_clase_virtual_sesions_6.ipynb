# %% [markdown]
# <a href="https://colab.research.google.com/github/usembergstarling-cmyk/google-colabt/blob/main/Resumen_video_clase_virtual_sesions_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ML de extremo a extremo
#
# ¿De datos crudos a decisiones rentables?
#
# Todo el tiempo escuchamos palabras de moda entre algoritmos y redes neuronales, aqui es donde conectamos los mundos, el machine learning se trata de construir un motor que se encargue construir decisiones.
#
# 1 vision y obtencion
# **Pipeline **componentes de procesamiento de datos asincronos, procesa la informacion y la pasa al siguiente paso, es un conjunto de sistemas aprueba de fallos
# primeros pasos es definir una meta, luego medir el exito y bajar datos
#
# 2 exploracion y visualizacion
# Tenemos que hacer un conjunto de prueba, un vistazo a los datos crudos inmobiliarios, datos sin refinar, es demasiada informacion, pero como lo preparamos?
#
# 3 preparacion de datos
#
# Es tomar los datos crudos desordenados y pulirla, se implementan conductos de limpieza automaticos, innovamos y hacemos ingenieria de caracteristicas, convinar atributos eleva mucho la calidad del algoritmo
#
# 4. Seleccion y entrenamiento
#
# Entramos a la sala de maquinas para elegir el cerebro algoritmico, probamos varios candidatos, **regresion lineal**, arboles de prediccion y diferentes algoritmos **dependiendo que lo que necesitamos**
# Termino **sobreajuste**, memoriza el entrenamiento pero falla al generalizar a casos nuevos.
#
# Tenemos que encontrar un caso de equilibrio donde veamos donde todas las etapas de hagan bien por ejemplo el **arbol aleatorio **
#
# Luego tenemos a la busqueda en cuadricula, le decimos a la computadora que opciones probar y evalua todas las opciones posibles, la mayoria de los expertos humanos se equivocaban en un 30%, pero los modelos no
#
# 6. Lanzamiento monitoreo y mantenimiento
#
# Es este el final de la historia? muchas vces existe la ilusion de que un proyecto termina al implementar el codigo, para mantenerlo se requiere infraestructura, deben existir scrips que entrenen al modelo de forma automatica para no entrar en la pudricion del modelo.
#
# Si los datos evolucionan debe actualizar y reentrenar el modelo
#
#
# Que joyas ocultas descubrira su empresa hoy?
#
# Recordemos el Pipeline
# **texto en negrita**
