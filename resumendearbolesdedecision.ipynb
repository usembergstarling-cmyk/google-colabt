# %% [markdown]
# <a href="https://colab.research.google.com/github/usembergstarling-cmyk/google-colabt/blob/main/resumendearbolesdedecision.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Arboles de decision**
#
# **Modelos de caja blanca**
# Algoritmos con reglas de clasificacion transparentes y faciles de interpretar paso a paso
#
# **Entrenando arboles de decision**
# Echando un vistaso dentro de la aja blanca, el arbol de decision entrnado con datos **Iris **, no necesitamos escalar ni normnalizar las caracteristicas antes de empezar, podemos usar los datos sin refinamiento, todo arranca del nodo raiz, nos ramificamos en los nodos de decision y luego en los nodos hoka
#
# **Predicciones y probabilidades **
# El camino que siguen los datos
# Inicio: raiz,
# Evaluacio: evaluac la condicion de division
# descenso: descender por la rama
# resultado: alcanzar hoja y calcular
#
# Se hacen fronteras de decision ortogonales en caracteristicas
#
# **Algoritmo CART**
# Arbol de clasificacion y regresion
# Buscamos minimizar la impureza, busca la mejor decision en ese instante exacto sin pensar en lo que va a pasar en etapas mas adelante ( no garantiza la perfeccion a largo plazo ) Jimmy y Entropia, son las dos opciones que se utilizan.
#
# **Regularización **}
# Tienen libertad para adaptarse a los datos y pueden memorizar cada ruido estadistico ( sobre ajuste ) para eso se aplica la regularizacion, se poda el algoritmo y le ponemos limites estrictos, minimo de datos o hasta donde puede crecer. Para que se vuelva regularizado.
#
# **Arboles de regresion para predecir valores continuos**
# Ahi entran los arboles de regresion, el nodo hoja ahora nos devuelve un valor continuo (el promedio de los datos de ese grupo), agrupa los datos de manera que sean lo mas identicos posibles, debe ser con restricciones ( regularizado )
#
# **Limitaciones y inestabilidad **
# El modelo es muy rigido, si los datos se separan facilmente con una linea diagonoal, el modelo se vuelve loco haciendo escaleeras y afecta sus resultados El talon de aquiles es su varianza, si cambiamos los datos de entrenamiento, pueden cambiar todo su diseño ante cualquier cambio de información, si se llega a actualizar algo se queda atras
# **Como superar esta alta varianza en los modelos**
# Tenemos los metodos de ensamble,, como los bosques aleatorios para poder construir uno de los sistemas predictivos mas fascinantes del mundo.
