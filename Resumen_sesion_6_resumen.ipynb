# %% [markdown]
# <a href="https://colab.research.google.com/github/usembergstarling-cmyk/google-colabt/blob/main/Resumen_sesion_6_resumen.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Reasonix un arnes para poder trabajar, es un arnes de deepsik que sirve para trabajar desde el computador
#
# Codex es un arnes de codigo de chatgpt es como un cowork para poder trabajar mejor, es un arnes de chatgpt
#
# Antigraviti es un arnes de Gemini, trabaja muy bien de forma local y tiene un poco de control en el navegador
#
# Autoclaw es el agente de orquestacion y de direccion de z.ai, esta z code y autoclaw para trabajar desde el computador y desde la web, puede manejar el computador de forma mas completa
#
# Open router sirve para hacer apis y conectarlas con otros modelos, pero debemmos tener dinero para tener tokens.
#
# Artificialanalisis ai para evaluar las ias, los costos, el tiempo, la calidad y el manejo de las ias y de los arneses
#
# Ermes
