# %% [markdown]
# <a href="https://colab.research.google.com/github/usembergstarling-cmyk/google-colabt/blob/main/2_resumen_sesion_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
CRISP DM RESUMEN

# %% [markdown]
# **CRISP DM el plano maestro**
# Como es que ejecutamos proyectos de datos en el mundo real para convertir datos crudos en decisiones estrategicas de negocio.
# los 90, mineria de datos era un caos total, pero luego las empresas gigantes hicieron un orden y crearon CRISP DM, estandar de oro para mineria de datos.
# **1 Origenes **
# Es comprension del negocio
# FASE 1
# objetivos
# situacion
# Metas de datos
# Plan
# **2 entender negocio y datos**
# Traducir un problema corporativo enorme
# FASE 2
# Recolectar
# Describir
# Explorar
# Calidad
# **3 Preparacion de datos**
# Que tan limpios estan nuestros datos?
# Tomamos esa informacion cruda y la transformamos con tecnicas de normalizacion comunes, hacemos ingenieria de caracteristicas, todo para transoformarla en un conjunto impecable de informacion valiosa y util.
# **4 Modelado y evaluacion**
# Puntos a tener en cuenta:
# Tecnica
# Prueba
# Construir
# Evaluacion:Resultados-Proceso-Proximo
# **5 Despliegue y futuro: **
# Etapas para desarrollar en esta fase:
# Despliegue
# Monitoreo
# Informe
# Revision
#
# Los resultados de seguir la metodologia CRISP DM hablan por si solos, mejoran las estadisticas y los resultados de cada area de la empresa, optimizando el dinero, el tiempo y la calidad de la empresa.
#
# CRISP DM a demostrado que se adapta a todo, pero con la IA moderna, el ciclo sigue mutando, ahora el nuevo entorno es la velocidad ¿Como se van a transformar estas 6 fases cuando los modelos de IA actuales comiencen automatizar el proceso.
