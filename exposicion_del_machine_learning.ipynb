# %% [markdown]
# <a href="https://colab.research.google.com/github/usembergstarling-cmyk/google-colabt/blob/main/exposicion_del_machine_learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Datos aprendizaje y predicciones
# Sin datos el modelo no puede aprender nada
# aprendizaje
# el modelo encuenta patrones de datos
# Con los patrones comienza a hacer patrones y con eso hace predicciones. Si los datos son malos las predicciones tambien lo seran por eso es tan importante el modelamiento de datos. Donde lo usa sin saberlo? Cuando nosotros utilizamos redes sociales, el contenido sugerido de estas plataformas es dada precisamente por el machinelearnign, en reconocimiento de fotos y demás cosas. Como se crea un modelo? tenemos 4 pasos, el primero es recolectar datos, juntamos ejemplos reales y para que los modelos de inteligencia aprendan, lo segundo es preparar datos, cuando limpiamos los datos y quedan listos para usarse, luego entrenamos el modelo, le hacemos preguntas y comienza el aprendizaje supervisado, el modelo aprende, lo probamos y ajustamos hasta que funcione bien. El flujo de modelo, el problema, que queremos predecir,definimos el objetivo del modelo, los datos los recolectamos y limpiamos el data set para entrenarlo, entreamiento para aprender patrones y la evaluacion.
# Ojo con esto, los modelos ml no son perfectos, hay cosas que considerar, necesita muchos datos para aprender bien, siempre hay que probarlo, hay que hacer scrips para actualizarlos. El machine learning vs la programacion tradicional, la maquina aprende sola, ella encuentra los patrones y no necesitamos dar las instrucciones paso a paso.
