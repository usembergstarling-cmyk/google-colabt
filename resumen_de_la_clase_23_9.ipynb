# %% [markdown]
# <a href="https://colab.research.google.com/github/usembergstarling-cmyk/google-colabt/blob/main/resumen_de_la_clase_23_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# PERCEPTRON, REDES NEURONALES, HERRAMIENTAS
#
# Redes neuronales con Keras,
#
# 1. De la biologia a las redes neuronales
# En el centro de una neurona hay un cuerpo celular y luego hay dendritas y axon, los axones liberan neuro transmisores y las dendritas hacen que se puedan buscar otras neuronas.
# Como pasamos de esa maravilla natural a una computadora? Las dentritas se vuelven las entradas y los axones se vuelven pesos numericos
#
# 2. Perceptron, el corazon del perceptron es la unidad logica Umbral (TLU) aplicando una funcion escalon, en 1969 nos topamos con una pared grande el OXR si los datos no se pueden pasar trazando una linea recta el perceptron no sirve
#
# 3. El perceptron multi capa (MLP) con capas ocultas, pasan por capas intermedias y ya no son lineas rectas, ya no interfiere el ORX y usa la retropropagacion que se basa en:
# adelante, medir error, pase inverso, paso de descenso de gradiente ( ajustar)
#
# 4. Como construimos verdaderamente estos modelos a la practica?
# API SECUENCIAL, el conjunto de datos Fashion MNIST un reemplazo moderno de MNIST
#
# 5. La API funcional de queras, red neuronal wide y deep conectando multiples rutas
#
# 6 La appi de subclases de keras, las demas secciones son declarativas, pero que pasa si el modelo debe cambiar su forma sobre la marcha?, al heredar la clase model se tiene el control total. La appi secuencial es el pan de cada dia resolviendo el 90 porcieto cada dia, la api funcional es el funcional cuando se necesitan resolver problemas complejos en varios caminos
#
# 7. Protegemos los modelos con codax, y usamos keras tuner y tensorboard.
#
# La mente artificial, introduccion a las redes neuronales y keras de la biologia a la arquitectura de sistemas
# La inspiracion biologica:
# Naturaleza: Dendritas son los receptores delas neuronas
# En software son las entradas ( inputs ).
# Maquina: Suma ponderada, se calcula la relevancia ( peso ) de cada entrada, el axon es u na funcion de activacion, decide si la neurona se enciende y emite una señal.
