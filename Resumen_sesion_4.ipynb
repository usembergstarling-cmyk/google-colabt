# %% [markdown]
# <a href="https://colab.research.google.com/github/usembergstarling-cmyk/google-colabt/blob/main/Resumen_sesion_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Ruta de ciencia de datos

# %% [markdown]
# **Ruta de ciencia de datos**
#  el objetivo de la guia es la claridad de organizar el ecosistema de los datos.
# **Por donde empezar en datos? **
# El mapa del cientifico de Datos
# **El mapa del cientifico**
# El plano para el ecosistema de datos, trabajos en ciencia de datos son cada vez mas populares, mrmimic
# **Motor logico**
# Fundamentals, Statistics, programming
# Son el engranaje central de cualquie profesional de datos, no se puede hacer machine learning sin antes estas 3 etapas.
# Fundamentals es la base matematica, algebraica, relacional y el teorema de CAP.
# **Capa inteligente**
# Machine Learn y Text mining le dan a una empresa un poder predictivo brutal
# El codigo empieza a imitar inteligencia humana.
# **El machine learning** aprende de datos con arboles de decision, naive y regresiones
# **Text mining NLP**, cpaacidad de las maquinas para leer y entender el lenguaje humano.
# **Infraestructura**
# **Data ingestion, Big Data, visualizacion**.
# 3 principios para refinar los datos
# **Data mungin** es el proceso de limpieza rigurosa, extraccion de caracteristicas y reduccion de ruido para que la calidad de lo que se prediga se mucho mejor deben limpiarse muy bien los datos.
# Despues de viajar por todo el sistema esa informacion llega a la estacion de visualizacion para convertir numeros que nadie entenderia en graficos hermosos y accionables. Pero que pasa cuando son demasiados datos que una computadora no puede procesarla?
# Para eso esta el **Big Data,** divide la informacion en diferentes areas. Una herramienta es el toolbox,tiene motores de procesamiento y es  una herramienta de equipo tactico.
# **Tu viaje al futuro **
# Siente libre de bifurcar este repositorio y enviar solicitudes, el plano esta dibujado pero necesita que nuevas mentes colaboren y aporten codigo al mapa de datos del cientifico de datos
# A que estacion viajaras primero en los datos?
